# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import numpy as np;
from sklearn.linear_model import LinearRegression;
from sklearn.model_selection import train_test_split;

# %%
df=pd.read_csv('Salary_Data.csv')
df
X=df.iloc[:,:-1].values
Y=df.iloc[:,-1].values

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=4)

# %%
reg=LinearRegression()
model=reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
accuracy=model.score(X,Y)
print((accuracy*100),"%")
# Out:
# 95.68938399623832 %

# %%
plt.scatter(x_train,y_train,color='red',marker='*',label='Sample Data')
plt.plot(x_train,reg.predict(x_train),color='blue',label='Regression Model')
plt.title("Salary Vs Years Of Experience")
plt.xlabel("Years Of Experience")
plt.ylabel("Salary")
plt.legend(facecolor='white',fontsize=11)
plt.show()

# %%
plt.scatter(x_test,y_test,color='red',marker='+')
plt.plot(x_test,reg.predict(x_test),color='green')
plt.title("Salary Vs Years Of Experience")
plt.xlabel("Years Of Experience")
plt.ylabel("Salary")
plt.show()

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
